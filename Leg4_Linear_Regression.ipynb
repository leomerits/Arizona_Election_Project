# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#loading cleaned data
file_path = "/Users/joshzaragoza/Arizona_Election_Project/Leg_District_4_outcome.csv"
df_voters = pd.read_csv(file_path)
df_voters.head(10)
# Out:
#    PartyName  Sex  Age    Zip  Ethnicity  PartisanScore  NatTO  Partisanship  \
# 0          1    1   66  85018          2             95     99            98
# 1          2    0   58  85254          3             11     99             7
# 2          2    0   59  85260          3              5     98             0
# 3          2    0   77  85016          3              7     98             0
# 4          2    1   70  85018          3              6     99             0
# 5          3    1   61  85018          3             30     90            25
# 6          3    0   58  85018          3             54     92            30
# 7          3    0   64  85018          3             15     99             1
# 8          2    1   79  85018          3              6     98             0
# 9          3    1   44  85251          3             70     35             1
#
#    2020:CivKidsinHH  2020:CivLibIdeo  2020:CivMarriage  Outcome
# ...

# %%
#Drop all columns contained unecesarry features or null nan 
df_voters.drop(columns=["Sex","Age","Zip","Ethnicity","NatTO","Partisanship","2020:CivKidsinHH","2020:CivLibIdeo","2020:CivMarriage","Outcome"], inplace=True)
df_voters
# Out:
#         PartyName  PartisanScore
# 0               1             95
# 1               2             11
# 2               2              5
# 3               2              7
# 4               2              6
# ...           ...            ...
# 123481          3             83
# 123482          2             12
# 123483          2              8
# 123484          1             95
# 123485          2             14
#
# [123486 rows x 2 columns]

# %%
plt.scatter(df_voters.PartyName, df_voters.PartisanScore)
plt.xlabel('PartyName')
plt.ylabel('PartisanScore')
plt.show()

# %%
#loading cleaned data
file_path = "/Users/joshzaragoza/Arizona_Election_Project/Leg_District_4_outcome.csv"
df_voters = pd.read_csv(file_path)
df_voters.head(10)
# Out:
#    PartyName  Sex  Age    Zip  Ethnicity  PartisanScore  NatTO  Partisanship  \
# 0          1    1   66  85018          2             95     99            98
# 1          2    0   58  85254          3             11     99             7
# 2          2    0   59  85260          3              5     98             0
# 3          2    0   77  85016          3              7     98             0
# 4          2    1   70  85018          3              6     99             0
# 5          3    1   61  85018          3             30     90            25
# 6          3    0   58  85018          3             54     92            30
# 7          3    0   64  85018          3             15     99             1
# 8          2    1   79  85018          3              6     98             0
# 9          3    1   44  85251          3             70     35             1
#
#    CivKidsinHH  CivLibIdeo  CivMarriage  Outcome
# 0           28          69           94        0
# ...

# %%
#Drop all columns contained unecesarry features or null nan 
df_voters.drop(columns=["PartyName","Sex","Age","Zip","Ethnicity","NatTO","Partisanship","CivLibIdeo","CivMarriage","Outcome"], inplace=True)
df_voters
# Out:
#         PartisanScore  CivKidsinHH
# 0                  95           28
# 1                  11           59
# 2                   5           64
# 3                   7            6
# 4                   6           16
# ...               ...          ...
# 123481             83            4
# 123482             12           19
# 123483              8           32
# 123484             95            0
# 123485             14           24
#
# [123486 rows x 2 columns]

# %%
plt.scatter(df_voters.CivKidsinHH, df_voters.PartisanScore)
plt.xlabel('CivKidsinHH')
plt.ylabel('PartisanScore')
plt.show()
