# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
import pandas as pd 
leg_voters_df = pd.read_csv("/Users/joshzaragoza/Arizona_Election_Project/AZ_Dummy_Voter_File.csv")
leg_voters_df.head()
# Out:
#    Voter File VANID       Party              mAddress   mCity mState  mZip5  \
# 0           4874086  Democratic     2134 E Copper St   Tucson     AZ  85719
# 1           4874240  Democratic    7562 E Fayette St   Tucson     AZ  85730
# 2           4875194  Democratic       1111 S Duke Dr   Tucson     AZ  85710
# 3           4875427  Democratic  7238 E Elbow Bay Pl   Tucson     AZ  85710
# 4           4875943  Democratic  3015 S Nicolette Dr   Tucson     AZ  85730
#
#     mZip4 Sex               Address    City  ... Suffix  CD  SD  HD  \
# 0  3212.0   F     2134 E Copper St   Tucson  ...    NaN   2   9   9
# 1  2415.0   M    7562 E Fayette St   Tucson  ...    NaN   2  10  10
# 2  8736.0   M       1111 S Duke Dr   Tucson  ...    NaN   2  10  10
# 3  1336.0   F  7238 E Elbow Bay Pl   Tucson  ...    NaN   2  10  10
# 4  6111.0   M  3015 S Nicolette Dr   Tucson  ...     Jr   2  10  10
#
#   PreferredEmail Age Partisan Score  Turnout Score  Ethnicity  Voting History
# ...

# %%
# Drop the non-beneficial ID columns.
leg_voters_df = leg_voters_df.drop(['mAddress','mCity','mState','mZip4','Address','City','LastName','FirstName','MiddleName','Suffix','PreferredEmail'], 1)
leg_voters_df.head()
# Out:
#    Voter File VANID       Party  mZip5 Sex State   Zip5    Zip4  CD  SD  HD  \
# 0           4874086  Democratic  85719   F    AZ  85719  3212.0   2   9   9
# 1           4874240  Democratic  85730   M    AZ  85730  2415.0   2  10  10
# 2           4875194  Democratic  85710   M    AZ  85710  8736.0   2  10  10
# 3           4875427  Democratic  85710   F    AZ  85710  1336.0   2  10  10
# 4           4875943  Democratic  85730   M    AZ  85730  6111.0   2  10  10
#
#    Age  Partisan Score  Turnout Score Ethnicity  Voting History
# 0   34              63             75     White               3
# 1   34              63             75     White               3
# 2   34              63             75     White               3
# 3   34              63             75     White               3
# 4   34              63             75     White               3

# %%
leg_voters_df = leg_voters_df.drop(['State','mZip5','Zip4'], 1)
leg_voters_df.head()
# Out:
#    Voter File VANID       Party Sex   Zip5  CD  SD  HD  Age  Partisan Score  \
# 0           4874086  Democratic   F  85719   2   9   9   34              63
# 1           4874240  Democratic   M  85730   2  10  10   34              63
# 2           4875194  Democratic   M  85710   2  10  10   34              63
# 3           4875427  Democratic   F  85710   2  10  10   34              63
# 4           4875943  Democratic   M  85730   2  10  10   34              63
#
#    Turnout Score Ethnicity  Voting History
# 0             75     White               3
# 1             75     White               3
# 2             75     White               3
# 3             75     White               3
# 4             75     White               3

# %%
# Determine the number of unique values in each column.
leg_voters_df.nunique()
# Out:
# Voter File VANID    9999
# Party                  3
# Sex                    3
# Zip5                  43
# CD                     7
# SD                    15
# HD                    15
# Age                    5
# Partisan Score         1
# Turnout Score          3
# Ethnicity              4
# Voting History         3
# dtype: int64

# %%
#importing possible libraries and dependencies
import pandas as pd
from path import Path
from sqlalchemy import create_engine
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Arizona_Elections"

# %%
leg_voters_df.to_sql(name='LegVoters', con=db_string)
