# %%
#importing possible libraries and dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
from path import Path
from config import db_password
from sqlalchemy import create_engine
from sqlalchemy import inspect
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#file path will be update to the table created in our sql database
file_path = "C:/Users/r_1rm/Arizona_Election_Project/Machine_learning - Copy/Leg_District_2.csv"
Leg_District_2_df = pd.read_csv(file_path)
Leg_District_2_df.head()
# Out:
#    Voter File VANID   PartyName Sex  Age CodedRaceName  LastName FirstName  \
# 0             99402  Republican   F   79  White (High)     Smidt     Susan
# 1             99440  Republican   F   97  White (High)    Neller   Beverly
# 2             99482  Republican   F   89  White (High)  Niemeier     Doris
# 3             99483  Republican   F   77  White (High)    Shelor     Donna
# 4             99521       Other   M   67  White (High)  McDonald   Michael
#
#   MiddleName Suffix  CD  ...  StreetPrefix  StreetName  StreetType  \
# 0    Theresa    NaN   1  ...             E      Meadow          Ln
# 1        NaN    NaN   1  ...             E    Michelle          Dr
# 2        Ann    NaN   1  ...             E    Michelle          Dr
# 3       Ruth    NaN   1  ...             W        Beck          Ln
# 4    Francis    NaN   1  ...             E    Michelle          Dr
#
#    StreetSuffix  AptType  AptNo     City  State   Zip5   Zip4
# ...

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Arizona_Elections"
engine = create_engine(db_string)

# %%
# seeing all data types
Leg_District_2_df.dtypes
# Out:
# Voter File VANID      int64
# PartyName            object
# Sex                  object
# Age                   int64
# CodedRaceName        object
#                      ...
# AptNo                object
# City                 object
# State                object
# Zip5                  int64
# Zip4                float64
# Length: 95, dtype: object

# %%
# Drop all columns contained unecesarry features or null nan
Leg_District_2_df.drop(columns=["Age","2016:DNC:DBRolRsk","CodedRaceName","CivPart.1","2016:DNC:AVEV",
                                "2016:DNC:AVEVTime","2016:DLCC:SCandSup","CodedRaceName","Partisan Score","DemPartySup"
                                ,"2016:DLCC:SGOTV","2016:DLCC:SPers","2016:DNCCatholic","2016:DNCCollegeGrad"
                                ,"2016:DNCDefectRisk","2016:DNCGenericDem","2016:DNCEvangelical","2016:DNCGenTurnoutV2"
                                ,"2016:DNCHighSchool","2016:DNCIncome","2016:DNCIssueCampFin","2016:DNCIssueClimate"
                                ,"2016:DNCIssueCollege","2016:DNCIssuePrivacy","2016:DNCIssueGunCtrl","2016:DNCIssueMinWage"
                                ,"2016:DNCIssuePdLeave","2016:DNCIssueCitizen","2016:DNCIssueChoice","2016:DNCIssueProgTax","2016:DNCNonChristian"
                                ,"2016:DNCOthChristian","2016:DNCVolPropV4","2016:DNCVolPrPhV4","2016:DNCVolPrWV4","KopTurnout2016","2020:CivMarriage"
                                ,"2016:TSM:ASDCDon","Healthcare","AntiGopInc","AntiGOP","KirkpatrickSup","TrmpChck"
                                ,"2018:Cla:DCCCTNT","AVEV","CultPers","EconPers","PoliPers","TrumpPers","DSCCTnt","BalDrop","State"
                                ,"CivGOTV","CivPart","CivRace","CivTnt","2018:DCCCBLHGS","SHGOTV","SHSup","SSGOTV","SSSup","Tnt"
                                ,"CodedRaceName","2018:TSM:MdGnTNT","2018:TSM:NatPart","2018:TSM:NPYPT","CivPart","YEARXXScoreSName"
                                ,"Partisanship","CivSpan","Covid","2020:VolProp","StreetNo","StreetNoHalf","StreetPrefix","StreetName"
                                ,"StreetType","StreetSuffix","AptType","AptNo","State","CD","HD","SD","Zip4 ","City","LastName"
                                ,"FirstName","MiddleName","Suffix"], inplace=True)
Leg_District_2_df
# Out:
#         Voter File VANID   PartyName Sex  2018:DNCDemSupport Ethnicity   \
# 0                  99402  Republican   F                3.29  Caucasian
# 1                  99440  Republican   F                5.15  Caucasian
# 2                  99482  Republican   F                3.56  Caucasian
# 3                  99483  Republican   F               15.52  Caucasian
# 4                  99521       Other   M               36.96  Caucasian
# ...                  ...         ...  ..                 ...        ...
# 103700            241525  Republican   F                3.23  Caucasian
# 103701            241548  Republican   F                7.86  Caucasian
# 103702            241582    Democrat   F               92.35  Caucasian
# 103703            241618  Republican   M                5.41  Caucasian
# 103704            241638    Democrat   F               88.58  Caucasian
#
#         NatTO  2020:CivKidsinHH  2020:CivLibIdeo   Zip5
# ...

# %%
# Columns
Leg_District_2_df.count()
# Out:
# Voter File VANID      103705
# PartyName             103705
# Sex                   103705
# 2018:DNCDemSupport     89133
# Ethnicity              89655
# NatTO                 103705
# 2020:CivKidsinHH       98574
# 2020:CivLibIdeo        98574
# Zip5                  103705
# dtype: int64

# %%
# seeing all data types
Leg_District_2_df.dtypes
# Out:
# Voter File VANID        int64
# PartyName              object
# Sex                    object
# 2018:DNCDemSupport    float64
# Ethnicity              object
# NatTO                 float64
# 2020:CivKidsinHH      float64
# 2020:CivLibIdeo       float64
# Zip5                    int64
# dtype: object

# %%
Leg_District_2_df.isnull()
# Out:
#         Voter File VANID  PartyName    Sex  2018:DNCDemSupport  Ethnicity   \
# 0                  False      False  False               False       False
# 1                  False      False  False               False       False
# 2                  False      False  False               False       False
# 3                  False      False  False               False       False
# 4                  False      False  False               False       False
# ...                  ...        ...    ...                 ...         ...
# 103700             False      False  False               False       False
# 103701             False      False  False               False       False
# 103702             False      False  False               False       False
# 103703             False      False  False               False       False
# 103704             False      False  False               False       False
#
#         NatTO  2020:CivKidsinHH  2020:CivLibIdeo   Zip5
# ...

# %%
#drop any null or nan in the data frame 
Leg_District_2_df.dropna(axis = 0, how = "any", thresh = None, subset = None, inplace=True)
Leg_District_2_df
# Out:
#         Voter File VANID   PartyName Sex  2018:DNCDemSupport Ethnicity   \
# 0                  99402  Republican   F                3.29  Caucasian
# 1                  99440  Republican   F                5.15  Caucasian
# 2                  99482  Republican   F                3.56  Caucasian
# 3                  99483  Republican   F               15.52  Caucasian
# 4                  99521       Other   M               36.96  Caucasian
# ...                  ...         ...  ..                 ...        ...
# 103700            241525  Republican   F                3.23  Caucasian
# 103701            241548  Republican   F                7.86  Caucasian
# 103702            241582    Democrat   F               92.35  Caucasian
# 103703            241618  Republican   M                5.41  Caucasian
# 103704            241638    Democrat   F               88.58  Caucasian
#
#         NatTO  2020:CivKidsinHH  2020:CivLibIdeo   Zip5
# ...

# %%
Leg_District_2_df.isnull().sum()
# Out:
# Voter File VANID      0
# PartyName             0
# Sex                   0
# 2018:DNCDemSupport    0
# Ethnicity             0
# NatTO                 0
# 2020:CivKidsinHH      0
# 2020:CivLibIdeo       0
# Zip5                  0
# dtype: int64

# %%
clean_District_2_df=Leg_District_2_df.dropna()
clean_District_2_df
# Out:
#         Voter File VANID   PartyName Sex  2018:DNCDemSupport Ethnicity   \
# 0                  99402  Republican   F                3.29  Caucasian
# 1                  99440  Republican   F                5.15  Caucasian
# 2                  99482  Republican   F                3.56  Caucasian
# 3                  99483  Republican   F               15.52  Caucasian
# 4                  99521       Other   M               36.96  Caucasian
# ...                  ...         ...  ..                 ...        ...
# 103700            241525  Republican   F                3.23  Caucasian
# 103701            241548  Republican   F                7.86  Caucasian
# 103702            241582    Democrat   F               92.35  Caucasian
# 103703            241618  Republican   M                5.41  Caucasian
# 103704            241638    Democrat   F               88.58  Caucasian
#
#         NatTO  2020:CivKidsinHH  2020:CivLibIdeo   Zip5
# ...

# %%
clean_District_2_df.rename(columns={"Zip5": "Zip", "PartyName": "Party", "2018:DNCDemSupport": "Voter Score","NatTO": "Turnout Score","2020:CivKidsinHH": "Kids in HH", "2020:CivLibIdeo": "Liberal Ideology"}, errors="raise")
# Out:
#         Voter File VANID       Party Sex  Voter Score Ethnicity   \
# 0                  99402  Republican   F         3.29  Caucasian
# 1                  99440  Republican   F         5.15  Caucasian
# 2                  99482  Republican   F         3.56  Caucasian
# 3                  99483  Republican   F        15.52  Caucasian
# 4                  99521       Other   M        36.96  Caucasian
# ...                  ...         ...  ..          ...        ...
# 103700            241525  Republican   F         3.23  Caucasian
# 103701            241548  Republican   F         7.86  Caucasian
# 103702            241582    Democrat   F        92.35  Caucasian
# 103703            241618  Republican   M         5.41  Caucasian
# 103704            241638    Democrat   F        88.58  Caucasian
#
#         Turnout Score  Kids in HH  Liberal Ideology    Zip
# 0               99.48        5.59              6.90  85022
# 1               96.51        0.76             10.88  85022
# ...
